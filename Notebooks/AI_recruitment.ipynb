# %% [markdown]
# # Gender Bias in Recruitment AI
#
# The AI at hand is to make recruitment decisions based on the candidates' interview performance. Let's try to make it less biased toward a certain gender.
#
# The code brings in historical recruitment data (`train.csv`) and new candidate data (`test.csv`). It learns from historical recruitment data, and performs a decision/prediction on the new candidates if they will get the job or not.

# %% [markdown]
# ## Training With Dataset1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
import gspread
from google.auth import default
#autenticating to google
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import os

# for dirname, _, filenames in os.walk('/content/drive/My Drive/data/'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# worksheet = gc.open('train1').sheet1
# rows = worksheet.get_all_values()
# df = pd.DataFrame(rows)
# df.columns = df.iloc[0]
# train_data = df.iloc[1:]

train_data = pd.read_csv("fair_dataset.csv")
test_data = pd.read_csv("test1.csv")

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["employed_yes"]

features = ["sex_male","interview_score"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)

predictions = model.predict(X_test)
test_data.columns.values[0] = "candidateID"
test_data.columns = test_data.columns.str.strip()
output = pd.DataFrame({'candidateid': test_data["candidateID"], 'gender':test_data.sex_male, 'score':test_data.interview_score, 'hired': predictions})
output
# output.to_csv('/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/output1.csv', index=False)
# print("Model Ran successfully! Please open output1.csv to view the data")
# Out:
#     candidateid  gender  score  hired
# 0             0       1     76      0
# 1             1       0     64      1
# 2             2       1     82      1
# 3             3       0     78      1
# 4             4       0     83      1
# ..          ...     ...    ...    ...
# 95           95       0     61      1
# 96           96       0     59      1
# 97           97       0     97      1
# 98           98       1     69      1
# 99           99       1     84      1
#
# [100 rows x 4 columns]

# %%
hired_df = output[output["hired"] == 1]
print(hired_df.shape[0])
hired_male_df = hired_df[hired_df["gender"] == 1]
print(hired_male_df.shape[0])
# Out:
# 87
# 37

# %% [markdown]
# ## Training With Dataset2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import os

# for dirname, _, filenames in os.walk('/content/drive/My Drive/data/'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# worksheet = gc.open('train2').sheet1
# rows = worksheet.get_all_values()
# df = pd.DataFrame(rows)
# df.columns = df.iloc[0]
# train_data = df.iloc[1:]

train_data = pd.read_csv("unfair_dataset-cleaned")
test_data = pd.read_csv("test1.csv")

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["employed_yes"]

features = ["sex_male","interview_score"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)

predictions = model.predict(X_test)
test_data.columns.values[0] = "candidateID"
test_data.columns = test_data.columns.str.strip()
output = pd.DataFrame({'candidateid': test_data.candidateID, 'gender':test_data.sex_male, 'score':test_data.interview_score, 'hired': predictions})
# output.to_csv('/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/output2.csv', index=False)
# print("Model Ran successfully! Please open output2.csv to view the data")

# %%
hired_df = output[output["hired"] == 1]
print(hired_df.shape[0])
hired_male_df = hired_df[hired_df["gender"] == 1]
print(hired_male_df.shape[0])
# Out:
# 80
# 37

# %%
import pandas as pd

pd_reader = pd.read_csv("/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/output2.csv")
print(pd_reader)
# Out:
#     candidateid gender score  hired
# 0            31      F     Y      1
# 1            32      M     N      0
# 2            33      F     N      0
# 3            34      F     N      0
# 4            35      M     N      0
# 5            36      M     N      0
# 6            37      M     N      0
# 7            38      M     N      0
# 8            39      M     N      0
# 9            40      M     N      0
# 10           41      F     N      0
# 11           42      F     N      0
# 12           43      F     N      0
# 13           44      F     N      0
# 14           45      M     N      0
# 15           46      M     N      0
# 16           47      M     N      0
# 17           48      M     Y      1
# 18           49      M     Y      1
# 19           50      M     Y      1
# 20           51      M     N      0
# 21           52      F     Y      1
# 22           53      F     Y      1
# 23           54      F     Y      1
# 24           55      F     N      0
# ...

# %% [markdown]
# ## Training With Dataset3

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import os

# for dirname, _, filenames in os.walk('/content/drive/My Drive/data/'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

worksheet = gc.open('train3').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame(rows)
df.columns = df.iloc[0]
train_data = df.iloc[1:]

# train_data = pd.read_csv("/content/drive/My Drive/data/train1.csv")
test_data = pd.read_csv("/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/test2.csv")

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["hired"]

features = ["gender","score"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)

predictions = model.predict(X_test)

output = pd.DataFrame({'candidateid': test_data.candidateid, 'gender':test_data.gender, 'score':test_data.score, 'hired': predictions})
output.to_csv('/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/output3.csv', index=False)
print("Model Ran successfully! Please open output3.csv to view the data")
# Out:
# Model Ran successfully! Please open output3.csv to view the data

# %%
import pandas as pd

pd_reader = pd.read_csv("/content/drive/My Drive/projects/current/gender bias education/recruitment lab/data/output3.csv")
print(pd_reader)
# Out:
#     candidateid gender score  hired
# 0            31      R     Y      1
# 1            32      R     N      0
# 2            33      R     N      0
# 3            34      R     N      0
# 4            35      R     N      0
# 5            36      R     N      0
# 6            37      R     N      0
# 7            38      R     N      0
# 8            39      R     N      0
# 9            40      R     N      0
# 10           41      R     N      0
# 11           42      R     N      0
# 12           43      R     N      0
# 13           44      R     N      0
# 14           45      R     N      0
# 15           46      R     N      0
# 16           47      R     N      0
# 17           48      R     Y      1
# 18           49      R     Y      1
# 19           50      R     Y      1
# 20           51      R     N      0
# 21           52      R     Y      1
# 22           53      R     Y      1
# 23           54      R     Y      1
# 24           55      R     N      0
# ...
